# %%
import matplotlib.pyplot as plt
labels='USA','India','Brazil','Russia','UK'
sizes=[48.995,18.516,18.386,7.155,6.948]
plt.pie(sizes,labels=labels,autopct='%1.1f%%',shadow=False,startangle=90)
plt.axis('equal')
plt.show()
